# %%
#參考資料 https://www.kaggle.com/outrunner/use-keras-to-count-sea-lions
# %matplotlib inline
import time
import numpy as np
import matplotlib.pyplot as plt
import skimage.feature
import os
import cv2
from tempfile import TemporaryFile

# %% [markdown]
# # dataset description
#
#
#   <font size =3 >
#   <table align="left" border="2" >
#   <tr> <td></td>                                       <td><font size=3>number</font></td><td><font size=3>size</font></td></tr>
#   <tr> <td><font size = 3>training data</font></td>    <td><font size=3>948   </font></td><td><font size=3>5.86GB</font></td></tr>
#   <tr> <td><font size = 3>training data dot</font></td><td><font size=3>948   </font></td><td><font size=3>3.95GB</font></td></tr>
#   <tr> <td><font size = 3>testing data</font></td>     <td><font size=3>18636 </font></td><td><font size=3>86GB</font></td></tr>
#   </table>
#   </font>

# %% [markdown]
# # training data: dataset distribution

# %%
#pixel_count = {'(3328, 4992, 3)': 458, '(3744, 5616, 3)':488, '(5616, 3744, 3)':2}
pixel_name  = ['(3328, 4992, 3)','(3744, 5616, 3)', '(5616, 3744, 3)']
pixel_num   = [458,488,2]
pixel_count_percent = [str(round(x/sum(pixel_num),2)*100)+'%' for x in pixel_num]
print(pixel_count_percent)

fig, ax = plt.subplots(1,1,figsize=(10,5))
width = 1/1.5
s1 = plt.bar(range(len(pixel_name)), pixel_count, width, color=('b','g','r'))
plt.legend(s1, pixel_count_percent,fontsize=15)
#plt.legend(s1, pixel_count_percent,fontsize=15)
plt.xticks(range(len(pixel_name)),pixel_name,fontsize=15 )
plt.xlabel('pixel infomation',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.text(0-0.1,200,str(pixel_num[0]),fontsize=20)
plt.text(1-0.1,200,str(pixel_num[1]),fontsize=20)
plt.text(2-0.1,20,str(pixel_num[2]),fontsize=20)
# Out:
# ['48.0%', '51.0%', '0.0%']

# %% [markdown]
# # testing data: dataset distribution

# %%
pixel_name  = ['(3744, 5616, 3)', '(3840, 5760, 3)','(3456, 4608, 3)', '(3456, 5184, 3)', '(5760, 3840, 3)','(881, 1280, 3)']
pixel_num   = [6983, 10718, 539, 390, 5, 1]

pixel_count_percent = [str(round(x/sum(pixel_num),2)*100)+'%' for x in pixel_num]
print(pixel_count_percent)

fig, ax = plt.subplots(1,1,figsize=(15,5))
width = 1/1.5
s1 = plt.bar(range(len(pixel_name)), pixel_num, width, color=('g','pink','r','y','brown','orange'))
plt.legend(s1, pixel_count_percent,fontsize=15)
#plt.legend(s1, pixel_count_percent,fontsize=15)
plt.xticks(range(len(pixel_name)),pixel_name,fontsize=15 )
plt.xlabel('pixel infomation',fontsize=20)
plt.ylabel('count',fontsize=20)
plt.text(0-0.2,4000,str(pixel_num[0]),fontsize=20)
plt.text(1-0.2,4000,str(pixel_num[1]),fontsize=20)
plt.text(2-0.1,1000,str(pixel_num[2]),fontsize=20)
plt.text(3-0.1,1000,str(pixel_num[3]),fontsize=20)
plt.text(4-0.1,1000,str(pixel_num[4]),fontsize=20)
plt.text(5-0.1,1000,str(pixel_num[5]),fontsize=20)
# Out:
# ['37.0%', '57.99999999999999%', '3.0%', '2.0%', '0.0%', '0.0%']

# %%
pixel_name  = ['(3744, 5616, 3)', '(3840, 5760, 3)','(3456, 4608, 3)', '(3456, 5184, 3)', '(5760, 3840, 3)','(881, 1280, 3)']
pixel_num   = [6983, 10718, 539, 390, 5, 1]

pixel_count_percent = [str(round(x/sum(pixel_num),2)*100)+'%' for x in pixel_num]

# %%
print(pixel_count_percent)
# Out:
# ['37.0%', '57.99999999999999%', '3.0%', '2.0%', '0.0%', '0.0%']

# %%
pixel_num[1]
# Out:
# 10718

# %%
round(pixel_num[1]/sum(pixel_num),2)
# Out:
# 0.58
