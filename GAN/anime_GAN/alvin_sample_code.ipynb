# %%
import glob

# %%
data_dir = "../../corpus/face/*.jpg"
data_dir = "../../corpus/faces/*.*"
all_data_dirlist = list(glob.glob(data_dir))

# %%
all_data_dirlist
# Out:
# ['../../corpus/faces/5812.jpg',
#  '../../corpus/faces/21028.jpg',
#  '../../corpus/faces/5434.jpg',
#  '../../corpus/faces/1712.jpg',
#  '../../corpus/faces/3765.jpg',
#  '../../corpus/faces/1.jpg',
#  '../../corpus/faces/3177.jpg',
#  '../../corpus/faces/16273.jpg',
#  '../../corpus/faces/2987.jpg',
#  '../../corpus/faces/29065.jpg',
#  '../../corpus/faces/8370.jpg',
#  '../../corpus/faces/19448.jpg',
#  '../../corpus/faces/459.jpg',
#  '../../corpus/faces/3400.jpg',
#  '../../corpus/faces/20208.jpg',
#  '../../corpus/faces/606.jpg',
#  '../../corpus/faces/17923.jpg',
#  '../../corpus/faces/19572.jpg',
#  '../../corpus/faces/31185.jpg',
#  '../../corpus/faces/28368.jpg',
#  '../../corpus/faces/1025.jpg',
#  '../../corpus/faces/29719.jpg',
#  '../../corpus/faces/29131.jpg',
#  '../../corpus/faces/470.jpg',
#  '../../corpus/faces/24135.jpg',
#  '../../corpus/faces/20216.jpg',
#  '../../corpus/faces/13990.jpg',
#  '../../corpus/faces/18876.jpg',
#  '../../corpus/faces/15595.jpg',
# ...
